# %% [markdown]
# <a href="https://colab.research.google.com/github/bunny-ml/ML_scratch/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linear regression

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X = np.linspace(0 , 100 , 60)

# %%
Y = 5 * X + 20

# %%
plt.title("Box plot of dataframe df1")
sns.boxplot(X)
plt.show()

# %%
plt.title("Barplot of df1")
sns.barplot( Y , color="green" )
plt.show()

# %%
plt.title("Barplot of df1")
sns.barplot( X , color="green" )
plt.show()

# %%
plt.title("Scatter plot of df1")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X,Y)
plt.show()

# %%
# linear model fit into the data set

# %%
# f(X) = W * x + b or Y = m * x + b
# W or m = slope
# b = intercet

# %%
m = X.shape
m
# Out:
# (60,)

# %%
# value of W and b

def calculate_w():

# %%
# linear regression in code
# f(X) = W * x + b


def linear_model():
    pass

# %%
# cost fuction

def mean_square_error():
    pass
