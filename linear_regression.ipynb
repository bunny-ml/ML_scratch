# %% [markdown]
# <a href="https://colab.research.google.com/github/bunny-ml/ML_scratch/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linear regression

# %%
import numpy as np
import seaborn as sns
import pandas as  pd
import matplotlib.pyplot as plt

# %%
X = np.random.uniform(high= 7, low=2 , size=100)
c = 2 # intercept

# %%
# add noise into the data
noise = np.random.normal(0 , 1, 100) # mean , std , number of eg

# %%
Y = 5 * X + c + noise

# %%
df = pd.DataFrame({'X': X , 'Y': Y})

# %%
plt.title("Box plot of dataframe df1")
sns.boxplot(df)
plt.show()

# %%
plt.title("Barplot of df1")
sns.barplot( df , color="green" )
plt.show()

# %%
plt.title("Barplot of df1")
sns.barplot( df['Y'] , color="green" )
plt.show()

# %%
plt.title("Scatter plot of df1")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(df['X'], df['Y'])
plt.show()

# %%
df.describe()
# Out:
#                 X           Y
# count  100.000000  100.000000
# mean     4.460262   24.275953
# std      1.516064    7.537876
# min      2.025583   11.978092
# 25%      3.104652   17.533809
# 50%      4.524362   24.442357
# 75%      5.778238   30.226892
# max      6.997668   37.673573

# %%
# linear model fit into the data set

# %%
alpha = 0.01
interations = 1000
theta = 0
m = df.shape[0]

# %%
for i in range(interations):
        y_hat = X @ theta # matrix wise multiplication and (y_hat = X @ theta) is model
        error = y_hat - Y
        gradient = (1/m) * (np.transpose(X) * error)
        theta = theta - alpha * gradient

# %%
intercept = theta[0]

# %%
slope = theta[1]

# %%
def predict(x_new):
    y_hat = intercept + slope * x_new
    return y_hat

# %%
# evaluate fit on training data

# %%
df.shape
# Out:
# (100, 2)

# %%
y_hat = X * theta

# %%
# value of W and b

def calculate_w():
    pass

# %%
# linear regression in code
# f(X) = W * x + b


def linear_model():
    pass

# %%
# cost fuction

def mean_square_error():
    pass
