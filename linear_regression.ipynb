# %% [markdown]
# <a href="https://colab.research.google.com/github/bunny-ml/ML_scratch/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linear regression

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = [ 1 , 2, 3, 4, 5, 1, 6,3 , 4, 7,2 , 4,1 , 8, 2 ,2, 7 ,9, 2 ,3, 2 ,3 , 2 ,2 , 2 ,1 ,2 ,2 , 1 ,1,2]

# %%
df1= np.array(df)

# %%
df1
# Out:
# array([1, 2, 3, 4, 5, 1, 6, 3, 4, 7, 2, 4, 1, 8, 2, 2, 7, 9, 2, 3, 2, 3,
#        2, 2, 2, 1, 2, 2, 1, 1, 2])

# %%
plt.title("Box plot of dataframe df1")
sns.boxplot(df1)
# Out:
# <Axes: title={'center': 'Box plot of dataframe df1'}>

# %%
plt.title("Barplot of df1")
sns.barplot(df1)
# Out:
# <Axes: title={'center': 'Barplot of df1'}>

# %%
plt.title("Scatter plot of df1")
sns.scatterplot(df1)
# Out:
# <Axes: title={'center': 'Scatter plot of df1'}>
